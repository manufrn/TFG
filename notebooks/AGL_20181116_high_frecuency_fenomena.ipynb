# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.path.append('/home/manu/TFG_repo/scripts')  # make modules in scripts folder callable from notebooks

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from utide import solve

# %%
from analysis_routines import *
from ploting_routines import *
from processing_routines import datenum_to_epoch
plt.style.use('/home/manu/TFG_repo/notebooks/notebook.mplstyle')

# %%
df = load_SHDR_fit('optimal_server_fit/AGL_20181116_fit_fci.csv')
temp, pres, date = load_time_series('processed/AGL_20181116_chain.nc')

# %%
date_1 = datetime(2018, 11, 22, 20)
date_2 = datetime(2018, 11, 23, 5)
plot_thermistor_temperature(temp, pres, date, [0,5,6,7,8], lims=[date_1, date_2])
plot_fit_variable(df, 'D1', lims=[date_1, date_2])

# %%
date_1 = datetime(2018, 11, 19, 19)
date_2 = datetime(2018, 11, 20, 6)
plot_thermistor_temperature(temp, pres, date, [0,5,6,7,8,9], lims=[date_1, date_2])
plot_thermistor_temperature(temp, pres, date, 8, lims=[date_1, date_2])
plot_fit_variable(df, 'D1', lims=[date_1, date_2])

# %%
date_1 = datetime(2018, 12, 12, 22)
date_2 = datetime(2018, 12, 13, 19)
plot_thermistor_temperature(temp, pres, date, [0, 1, 3, 4], lims=[date_1, date_2])

# %%
display_video('internal_wave_2.mp4')
# Out:
# <video controls  width="500" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
plot_column_temperature(temp, date, df, lims=[date_1, date_2], interval=timedelta(seconds=5))

# %%
date_5 = datetime(2018, 11, 18, 4)
date_6 = datetime(2018, 11, 18, 13)

plot_thermistor_temperature(temp, pres, date, [0,5,6,7,8], lims=[date_5, date_6])
plot_fit_variable(df, 'D1', lims=[date_5, date_6])

# %%
date_7 = datetime(2018, 11, 21, 8)
date_8 = datetime(2018, 11, 21, 16)
plot_thermistor_temperature(temp, pres, date, [0, 5,6,7, 8, 9], lims=[date_7, date_8])
plot_fit_variable(df, 'D1', lims=[date_7, date_8])

# %%
animate_profile_evolution(df, temp, pres, 'internal_wave_3.mp4', start_loc = date_3, final_loc = date_4)

# %%
display_video('internal_wave_3.mp4')
# Out:
# <video controls  width="500" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
date_9 = datetime(2018, 11, 21, 21)
date_10 = datetime(2018, 11, 22, 6)

plot_thermistor_temperature(temp, pres, date, [0,5,6,7,8], lims=[date_9, date_10])
plot_fit_variable(df, 'D1', lims=[date_9, date_10])

# %%
date_11 = datetime(2018, 11, 22, 6)
date_12 = datetime(2018, 11, 22, 18)
plot_thermistor_temperature(temp, pres, date, [0,5,6,7,8], lims=[date_11, date_12])
plot_fit_variable(df, 'D1', lims=[date_11, date_12])

# %%
date_13 = datetime(2018, 11, 18, 18)
date_14 = datetime(2018, 11, 19, 1)
plot_thermistor_temperature(temp, pres, date, [0,5,6,7,8], lims=[date_13, date_14])
plot_fit_variable(df, 'D1', lims=[date_13, date_14])

# %%
date_13 = datetime(2018, 12, 6, 0)
date_14 = datetime(2018, 12, 6, 12)
plot_thermistor_temperature(temp, pres, date, [7,8,9,10], lims=[date_13, date_14])
plot_fit_variable(df, 'D1', lims=[date_13, date_14])
