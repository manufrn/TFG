# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.path.append('/home/manu/TFG_repo/scripts')  # make modules in scripts folder callable from notebooks
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
plt.style.use('/home/manu/TFG_repo/notebooks/notebook.mplstyle')

# %%
from analysis_functions import *

# %%
temp, pres, date, lat, lon = load_time_series('AGL_1_SB56.h5')

# %%
plot_single_thermistor(temp, pres, date, 7, lims=[0, 10000])

# %%
plot_single_thermistor(temp, pres, date, 8, lims=[0, 10000])

# %%
plot_single_thermistor(temp, pres, date, 9, lims=[0, 10000])

# %%
plot_column_temperature(temp, pres, date, lims=[0, 3000], interval=1)
