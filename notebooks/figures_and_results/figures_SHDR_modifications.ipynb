# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.path.append('/home/manu/TFG_repo/scripts')  # make modules in scripts folder callable from notebooks

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from datetime import datetime, timedelta, timezone
from scipy.interpolate import interp1d, splrep, splev
from datetime import timezone
from numba import njit
sys.path.append('/home/manu/TFG_repo/scripts')

# %%
from config import data_dir
from analysis_routines import *
from ploting_routines import *
plt.style.use('/home/manu/TFG_repo/notebooks/notebook.mplstyle')

# %%
temp, pres, date = load_time_series('processed/AGL_20181116_chain.nc')

# %%
df_g = load_SHDR_fit('old_fits/AGL_1_SB56_Grenoble.csv')
df_s = load_SHDR_fit('optimal_server_fit/AGL_20181116_fit_s.csv')

# %%
df_g['date']
# Out:
# 0          1.573898e+09
# 1          1.573898e+09
# 2          1.573898e+09
# 3          1.573898e+09
# 4          1.573898e+09
#                ...
# 2487601    1.586333e+09
# 2487602    1.586333e+09
# 2487603    1.586333e+09
# 2487604    1.586333e+09
# 2487605    1.586333e+09
# Name: date, Length: 2487606, dtype: float64

# %%
locs = np.where(df_g['b3'] < -0.03)[0]

# %%
plot_multiple_profiles(df_g, temp, pres, locs[:10])

# %%
plot_multiple_profiles(df_s, temp, pres, locs[:10])
