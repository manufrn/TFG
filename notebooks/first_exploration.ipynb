# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.path.append('/home/manu/TFG_repo/scripts')  # make modules in scripts folder callable from notebooks

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
plt.style.use('/home/manu/TFG_repo/notebooks/notebook.mplstyle')

# %%
from analysis_functions import *

# %%
temp, pres, date, lat, lon = load_time_series('AGL_1_SB56_3000.h5')
df_fit = load_SHDR_fit('AGL_1_SB56_3000_fit.csv')

# %%
plot_fit_variable(df_fit, 'b2')

# %%
plot_profile_fit(df_fit, temp, pres, 1)
find_thermocline_thermistors(df_fit, pres, temp, 1)
# Out:
# [43.0, 53.0, 63.0, 78.0, 96.0, 108.0, 126.0, 151.0, 176.0]

# %%
plot_RMS_fit(df_fit, temp, pres, 2)

# %%
plot_multiple_profiles(df_fit, temp, pres, (1, 2, 3, 4))
