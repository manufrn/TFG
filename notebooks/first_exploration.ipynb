# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.path.append('/home/manu/TFG_repo/scripts')  # make modules in scripts folder callable from notebooks

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
plt.style.use('/home/manu/TFG_repo/notebooks/notebook.mplstyle')

# %%
from analysis_functions import *

# %%
temp, pres, date, lat, lon = load_time_series('AGL_1_SB56.h5')
df_fit = load_SHDR_fit('AGL_1_SB56_fit.csv')

# %%
print(f'Time series ranging from {df_fit.iloc[0, 0]} to {df_fit.iloc[-1, 0]}')
# Out:
# Time series ranging from 2019-11-16 11:00:00 to 2020-04-08 10:00:24

# %%
plot_fit_variable(df_fit, 'D1', interval=timedelta(seconds=60))

# %%
plot_profile_fit(df_fit, temp, pres, 1)

# %%
plot_RMS_fit(df_fit, temp, pres, 2)

# %%
plot_multiple_profiles(df_fit, temp, pres, (1, 2, 3, 4))

# %%
plot_profile_fit(df_fit, temp, pres, datetime(2019, 11, 17, 10, 1, 10))
