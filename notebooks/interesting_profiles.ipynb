# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.path.append('/home/manu/TFG_repo/scripts')  # make modules in scripts folder callable from notebooks

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
plt.style.use('/home/manu/TFG_repo/notebooks/notebook.mplstyle')

# %%
from analysis_functions import *

# %%
temp, pres, date, lat, lon = load_time_series('AGL_1_SB56.h5')
df_fit = load_SHDR_fit('AGL_1_SB56_fit.csv')

# %% [markdown]
# ### Variabilidad capa de mezcla en invierno

# %%
locs = np.linspace(349200, 372600, 26, dtype='int')
plot_multiple_profiles(df_fit, temp, pres, locs)

# %%
plot_single_thermistor(temp, pres, date, 6, lims=(datetime(2019, 12, 6, 0, 59, 59), datetime(2019, 12, 6, 19, 35, 59)))

# %%
locs = np.linspace(11000, 29000, 26, dtype='int')
plot_multiple_profiles(df_fit, temp, pres, locs)

# %%
date1 = datetime(2019, 11, 17, 0, 46, 39)
date2 = date1 + timedelta(hours=24)
plot_single_thermistor(temp, pres, date, 6, lims=(date1, date2))
